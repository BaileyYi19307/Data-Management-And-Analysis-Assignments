# %% [markdown]
# # Part 1 - Combine Course Info with Requirements

# %% [markdown]
# ## 1. Read the course schedule into a DataFrame

# %%
import pandas as pd
from bs4 import BeautifulSoup
import re


#read in course_schedule
with open("course_Schedule.html", "r", encoding="utf-8") as f:
    body = f.read()
dom= BeautifulSoup(body, "lxml")
dom.head()

#select div class=faculty 
type(dom.select('.faculty'))

for faculty in dom.select(".faculty"):
    row_items = faculty.select("li.row")

courses=[]
for i in range(len(row_items)):
    number_section=list(filter(lambda x: x!="" ,row_items[i].select("span")[0].getText().replace('\u200b', '').split(" ")))[0].strip().split("\n")
    course_name = " ".join([line.strip() for line in row_items[i].select("span")[1].text.strip().split("\n") if line.strip()])
    instructor=row_items[i].select("span")[2].getText().strip()
    time=row_items[i].select("span")[3].getText()
    #if more than two number_sections
    
    if len(number_section) > 1:
        #for each one, we make a copy of the data and append to courses
        for number_sec in number_section:
            course_info = [number_sec, course_name,instructor,time]
            courses.append(course_info)
    else:
        courses.append([number_section, course_name, instructor, time])

course_schedule_df=pd.DataFrame(courses,columns=["Number-Section","Name","Instructor","Time"])
course_schedule_df[['Number','Section']]=course_schedule_df["Number-Section"].str.extract(r'(.*)-(\d{3})')
course_schedule_df
# Out:
#        Number-Section                                               Name  \
# 0    CSCI-GA.1170-001                             Fundamental Algorithms
# 1      DS-GA.1170-001                             Fundamental Algorithms
# 2    CSCI-GA.1170-002                  Fundamental Algorithms Recitation
# 3      DS-GA.1170-002                  Fundamental Algorithms Recitation
# 4    CSCI-GA.1170-003                  Fundamental Algorithms Recitation
# ..                ...                                                ...
# 347           (16906)  Special Topics: Agile Software Development and...
# 348  CSCI-UA.0480-075      Special Topics: Introduction to Deep Learning
# 349           (23956)      Special Topics: Introduction to Deep Learning
# 350  CSCI-UA.0490-001            Special Topics in Programming Languages
# 351           (23952)            Special Topics in Programming Languages
#
#             Instructor              Time        Number Section
# 0             Chee Yap     W 4:55-6:55PM  CSCI-GA.1170     001
# 1             Chee Yap     W 4:55-6:55PM    DS-GA.1170     001
# 2        Bingwei Zhang     R 5:55-6:45PM  CSCI-GA.1170     002
# 3        Bingwei Zhang     R 5:55-6:45PM    DS-GA.1170     002
# 4        Bingwei Zhang     F 4:55-5:45PM  CSCI-GA.1170     003
# ..                 ...               ...           ...     ...
# 347     Amos Bloomberg  MW 11:00-12:15PM           NaN     NaN
# 348   Alfredo Canziani   TR 12:30-1:45PM  CSCI-UA.0480     075
# 349   Alfredo Canziani   TR 12:30-1:45PM           NaN     NaN
# 350  Benjamin Goldberg    MW 3:30-4:45PM  CSCI-UA.0490     001
# 351  Benjamin Goldberg    MW 3:30-4:45PM           NaN     NaN
#
# [352 rows x 6 columns]

# %%
display(course_schedule_df.info())
display(course_schedule_df.head(5))
display(course_schedule_df.tail(5))
display(course_schedule_df.sample(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352 entries, 0 to 351
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Number-Section  352 non-null    object
#  1   Name            352 non-null    object
#  2   Instructor      352 non-null    object
#  3   Time            352 non-null    object
#  4   Number          183 non-null    object
#  5   Section         183 non-null    object
# dtypes: object(6)
# memory usage: 16.6+ KB
# None
#      Number-Section                               Name     Instructor  \
# 0  CSCI-GA.1170-001             Fundamental Algorithms       Chee Yap
# 1    DS-GA.1170-001             Fundamental Algorithms       Chee Yap
# 2  CSCI-GA.1170-002  Fundamental Algorithms Recitation  Bingwei Zhang
# 3    DS-GA.1170-002  Fundamental Algorithms Recitation  Bingwei Zhang
# 4  CSCI-GA.1170-003  Fundamental Algorithms Recitation  Bingwei Zhang
#
#             Time        Number Section
# 0  W 4:55-6:55PM  CSCI-GA.1170     001
# 1  W 4:55-6:55PM    DS-GA.1170     001
# 2  R 5:55-6:45PM  CSCI-GA.1170     002
# 3  R 5:55-6:45PM    DS-GA.1170     002
# 4  F 4:55-5:45PM  CSCI-GA.1170     003
#        Number-Section                                               Name  \
# 347           (16906)  Special Topics: Agile Software Development and...
# 348  CSCI-UA.0480-075      Special Topics: Introduction to Deep Learning
# 349           (23956)      Special Topics: Introduction to Deep Learning
# 350  CSCI-UA.0490-001            Special Topics in Programming Languages
# 351           (23952)            Special Topics in Programming Languages
#
#             Instructor              Time        Number Section
# 347     Amos Bloomberg  MW 11:00-12:15PM           NaN     NaN
# 348   Alfredo Canziani   TR 12:30-1:45PM  CSCI-UA.0480     075
# 349   Alfredo Canziani   TR 12:30-1:45PM           NaN     NaN
# 350  Benjamin Goldberg    MW 3:30-4:45PM  CSCI-UA.0490     001
# 351  Benjamin Goldberg    MW 3:30-4:45PM           NaN     NaN
#        Number-Section                                        Name  \
# 46   CSCI-GA.2572-002                           Deep Learning Lab
# 260  CSCI-UA.0201-002  Computer Systems Organization - Recitation
# 293           (16890)                            Basic Algorithms
# 59             (5174)              DevOps and Agile Methodologies
# 201           (16845)                   Intro To Computer Science
#
#           Instructor             Time        Number Section
# 46               TBA    W 3:45-4:35PM  CSCI-GA.2572     002
# 260       Anway Agte   F 9:30-10:45AM  CSCI-UA.0201     002
# 293     Rotem Oshman   MW 3:30-4:45PM           NaN     NaN
# 59      John Rofrano    W 4:55-6:55PM           NaN     NaN
# 201  Tobias Blickhan  MW 9:30-10:45AM           NaN     NaN

# %% [markdown]
# ## 2. Read the course catalog into a DataFrame

# %%
with open("course_catalog.html", "r", encoding="utf-8") as f:
    body = f.read()
dom= BeautifulSoup(body, "lxml")
courses=dom.select(".courses-listing")[0].select("li")

catalogue=[]
for i in range(len(courses)):
    number=re.search(r".+.\d{4}",courses[i].select("p")[0].getText().strip())[0]
    points=re.search(r"(.+) Points",courses[i].select("p")[1].getText())[1].strip()
    prereqs=courses[i].select("p")[2].getText()[15:]
    catalogue.append([number,prereqs,points])

# %%
course_catalogue_df=pd.DataFrame(catalogue,columns=["Number","Prereqs","Points"])

display(course_catalogue_df.info())
display(course_catalogue_df.head(5))
display(course_catalogue_df.tail(5))
display(course_catalogue_df.sample(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Number   96 non-null     object
#  1   Prereqs  96 non-null     object
#  2   Points   96 non-null     object
# dtypes: object(3)
# memory usage: 2.4+ KB
# None
#          Number                                            Prereqs Points
# 0  CSCI-GA.1170  At least one year of experience with a high-le...      3
# 1  CSCI-GA.1180                                               None      3
# 2  CSCI-GA.2110  Students taking this class should already have...      3
# 3  CSCI-GA.2112  Multivariate calculus and linear algebra. Some...      3
# 4  CSCI-GA.2130      CSCI-GA 1170, CSCI-GA 2110, and CSCI-GA 2250.      3
#            Number                                            Prereqs Points
# 91   CSCI-UA.0897  Restricted to declared computer science majors...  1 - 4
# 92   CSCI-UA.0898  Restricted to declared computer science majors...  1 - 4
# 93   CSCI-UA.0997  Permission of the department. Does not satisfy...  1 - 4
# 94   CSCI-UA.0998  Permission of the department. Does not satisfy...  1 - 4
# 95  FRSEM-UA.0597  Some programming experience in Python, Java, J...      4
#           Number                                            Prereqs Points
# 7   CSCI-GA.2250                                               None      3
# 37  CSCI-GA.2830                                               None      3
# 86  CSCI-UA.0479  Data Structures (CSCI-UA 102). Students that c...      4
# 14  CSCI-GA.2420                       Corequisite: linear algebra.      3
# 78  CSCI-UA.0469       Computer Systems Organization (CSCI-UA 201).      4

# %% [markdown]
# ## 3. Put together both DataFrames

# %%
# merge catalogue info onto scheduled courses
merged_df = pd.merge(course_schedule_df, course_catalogue_df, on="Number", how="left")
final_df = merged_df[["Number", "Name", "Instructor", "Time", "Prereqs", "Points"]]
final_df
# Out:
#            Number                                               Name  \
# 0    CSCI-GA.1170                             Fundamental Algorithms
# 1      DS-GA.1170                             Fundamental Algorithms
# 2    CSCI-GA.1170                  Fundamental Algorithms Recitation
# 3      DS-GA.1170                  Fundamental Algorithms Recitation
# 4    CSCI-GA.1170                  Fundamental Algorithms Recitation
# ..            ...                                                ...
# 347           NaN  Special Topics: Agile Software Development and...
# 348  CSCI-UA.0480      Special Topics: Introduction to Deep Learning
# 349           NaN      Special Topics: Introduction to Deep Learning
# 350  CSCI-UA.0490            Special Topics in Programming Languages
# 351           NaN            Special Topics in Programming Languages
#
#             Instructor              Time  \
# 0             Chee Yap     W 4:55-6:55PM
# 1             Chee Yap     W 4:55-6:55PM
# 2        Bingwei Zhang     R 5:55-6:45PM
# 3        Bingwei Zhang     R 5:55-6:45PM
# 4        Bingwei Zhang     F 4:55-5:45PM
# ..                 ...               ...
# 347     Amos Bloomberg  MW 11:00-12:15PM
# 348   Alfredo Canziani   TR 12:30-1:45PM
# 349   Alfredo Canziani   TR 12:30-1:45PM
# 350  Benjamin Goldberg    MW 3:30-4:45PM
# 351  Benjamin Goldberg    MW 3:30-4:45PM
#
#                                                Prereqs Points
# 0    At least one year of experience with a high-le...      3
# 1                                                  NaN    NaN
# 2    At least one year of experience with a high-le...      3
# 3                                                  NaN    NaN
# 4    At least one year of experience with a high-le...      3
# ..                                                 ...    ...
# 347                                                NaN    NaN
# 348                    Topics determine prerequisites.      4
# 349                                                NaN    NaN
# 350                    Topics determine prerequisites.      4
# 351                                                NaN    NaN
#
# [352 rows x 6 columns]

# %% [markdown]
# ## 4. Conclusion

# %% [markdown]
# #### **Issues**
# 1. Invisible Zero-Width Spaces
#    - Some course numbers (e.g., CSCI-GA.1170-​001) contained hidden spaces (\u200b)-> removed these spaces (i.e. used .replace('\u200b', ''))
#
# 2. Courses with Multiple Numbers
#    - Courses like CSCI-GA.1170-001 and DS-GA.1170-001 (5115) shared the same section but had different number sections -> split these into separate rows to preserve all course numbers
#
#
# #### **Behavior of how='left' Merge**
# - Keep every row from the course_schedule (left dataframe)
# - Add matching data from the course catalogue (right dataframe) where possible and leave NaN where no match exists

# %% [markdown]
# # Part 2 - Using an API

# %% [markdown]
# ## 1. Retrieve the data, and examine it.

# %%
import requests
import pandas as pd

url= "http://linserv1.cims.nyu.edu:10000/films?_page=1"
# url = "https://ghibliapi.vercel.app/films"

response = requests.get(url)
films = response.json()

# %% [markdown]
# - Interested in the director and rt_score keys to get the report
# - When I modify the url, it returns a separate set of movies. Going past page 3 reveals nothing - so there are  3 pages of movie info

# %% [markdown]
# ## 2. Load the data into a DataFrame

# %%
df = pd.DataFrame(films)

for i in range(2,4):
    url= f"http://linserv1.cims.nyu.edu:10000/films?_page={i}"
    response = requests.get(url)
    films = response.json()
    temp_df=pd.DataFrame(films)
    df=pd.concat([df, temp_df])

df=df.reset_index()
df
# Out:
#     index                                    id  \
# 0       0  d868e6ec-c44a-405b-8fa6-f7f0f8cfb500
# 1       0  dc2e6bd1-8156-4886-adff-b39e6043af0c
# 2       1  90b72513-afd4-4570-84de-a56c312fdf81
# 3       2  cd3d059c-09f4-4ff3-8d63-bc765a5184fa
# 4       3  112c1e67-726f-40b1-ac17-6974127bb9b9
# 5       4  758bf02e-3122-46e0-884e-67cf83df1786
# 6       5  2de9426b-914a-4a06-a3a0-5e6d9d3886f6
# 7       6  45db04e4-304a-4933-9823-33f389e8d74d
# 8       7  67405111-37a5-438f-81cc-4666af60c800
# 9       8  578ae244-7750-4d9f-867b-f3cd3d6fecf4
# 10      9  5fdfb320-2a02-49a7-94ff-5ca418cae602
# 11      0  d868e6ec-c44a-405b-8fa6-f7f0f8cfb500
#
#                               title  original_title  \
# 0                    The Red Turtle  レッドタートル ある島の物語
# 1                     Spirited Away        千と千尋の神隠し
# 2                   The Cat Returns           猫の恩返し
# 3              Howl's Moving Castle         ハウルの動く城
# 4               Tales from Earthsea            ゲド戦記
# 5                             Ponyo         崖の上のポニョ
# 6                          Arrietty    借りぐらしのアリエッティ
# 7             From Up on Poppy Hill         コクリコ坂から
# 8                    The Wind Rises            風立ちぬ
# 9   The Tale of the Princess Kaguya         かぐや姫の物語
# 10            When Marnie Was There        思い出のマーニー
# 11                   The Red Turtle  レッドタートル ある島の物語
#
#                original_title_romanised  \
# 0   Reddotātoru aru shima no monogatari
# 1         Sen to Chihiro no kamikakushi
# 2                      Neko no ongaeshi
# 3                  Hauru no ugoku shiro
# 4                            Gedo senki
# 5                   Gake no ue no Ponyo
# 6                Karigurashi no Arietti
# 7                    Kokuriko zaka kara
# 8                          Kaze tachinu
# 9             Kaguya-Hime no Monogatari
# 10                     Omoide no Marnie
# 11  Reddotātoru aru shima no monogatari
#
#                                           description              director  \
# 0   A man set adrift by a storm wakes up on a beac...  Michaël Dudok de Wit
# 1   Spirited Away is an Oscar winning Japanese ani...        Hayao Miyazaki
# 2   Haru, a schoolgirl bored by her ordinary routi...       Hiroyuki Morita
# 3   When Sophie, a shy young woman, is cursed with...        Hayao Miyazaki
# 4   Something bizarre has come over the land. The ...         Gorō Miyazaki
# 5   The son of a sailor, 5-year old Sosuke lives a...        Hayao Miyazaki
# 6   14-year-old Arrietty and the rest of the Clock...  Hiromasa Yonebayashi
# 7   The story is set in 1963 in Yokohama. Kokuriko...         Gorō Miyazaki
# 8   A lifelong love of flight inspires Japanese av...        Hayao Miyazaki
# 9   A bamboo cutter named Sanuki no Miyatsuko disc...         Isao Takahata
# 10  The film follows Anna Sasaki living with her r...  Hiromasa Yonebayashi
# 11  A man set adrift by a storm wakes up on a beac...  Michaël Dudok de Wit
#
#                                              producer release_date  \
# 0   Toshio Suzuki, Isao Takahata, Vincent Maraval,...         2016
# 1                                       Toshio Suzuki         2001
# 2                                       Toshio Suzuki         2002
# 3                                       Toshio Suzuki         2004
# 4                                       Toshio Suzuki         2006
# 5                                       Toshio Suzuki         2008
# 6                                       Toshio Suzuki         2010
# 7                                       Toshio Suzuki         2011
# 8                                       Toshio Suzuki         2013
# 9                                  Yoshiaki Nishimura         2013
# 10                                 Yoshiaki Nishimura         2014
# 11  Toshio Suzuki, Isao Takahata, Vincent Maraval,...         2016
#
#    running_time rt_score                                     people  \
# 0            80       93  [https://ghibliapi.herokuapp.com/people/]
# 1           124       97  [https://ghibliapi.herokuapp.com/people/]
# 2            75       89  [https://ghibliapi.herokuapp.com/people/]
# 3           119       87  [https://ghibliapi.herokuapp.com/people/]
# 4           116       41  [https://ghibliapi.herokuapp.com/people/]
# 5           100       92  [https://ghibliapi.herokuapp.com/people/]
# 6            94       95  [https://ghibliapi.herokuapp.com/people/]
# 7            91       83  [https://ghibliapi.herokuapp.com/people/]
# 8           126       89  [https://ghibliapi.herokuapp.com/people/]
# 9           137      100  [https://ghibliapi.herokuapp.com/people/]
# 10          103       92  [https://ghibliapi.herokuapp.com/people/]
# 11           80       93  [https://ghibliapi.herokuapp.com/people/]
#
#                                               species  \
# 0          [https://ghibliapi.herokuapp.com/species/]
# 1   [https://ghibliapi.herokuapp.com/species/af391...
# 2   [https://ghibliapi.herokuapp.com/species/af391...
# 3   [https://ghibliapi.herokuapp.com/species/af391...
# 4   [https://ghibliapi.herokuapp.com/species/af391...
# 5   [https://ghibliapi.herokuapp.com/species/af391...
# 6   [https://ghibliapi.herokuapp.com/species/af391...
# 7   [https://ghibliapi.herokuapp.com/species/af391...
# 8   [https://ghibliapi.herokuapp.com/species/af391...
# 9   [https://ghibliapi.herokuapp.com/species/af391...
# 10  [https://ghibliapi.herokuapp.com/species/af391...
# 11         [https://ghibliapi.herokuapp.com/species/]
#
#                                        locations  \
# 0   [https://ghibliapi.herokuapp.com/locations/]
# 1   [https://ghibliapi.herokuapp.com/locations/]
# 2   [https://ghibliapi.herokuapp.com/locations/]
# 3   [https://ghibliapi.herokuapp.com/locations/]
# 4   [https://ghibliapi.herokuapp.com/locations/]
# 5   [https://ghibliapi.herokuapp.com/locations/]
# 6   [https://ghibliapi.herokuapp.com/locations/]
# 7   [https://ghibliapi.herokuapp.com/locations/]
# 8   [https://ghibliapi.herokuapp.com/locations/]
# 9   [https://ghibliapi.herokuapp.com/locations/]
# 10  [https://ghibliapi.herokuapp.com/locations/]
# 11  [https://ghibliapi.herokuapp.com/locations/]
#
#                                        vehicles  \
# 0   [https://ghibliapi.herokuapp.com/vehicles/]
# 1   [https://ghibliapi.herokuapp.com/vehicles/]
# 2   [https://ghibliapi.herokuapp.com/vehicles/]
# 3   [https://ghibliapi.herokuapp.com/vehicles/]
# 4   [https://ghibliapi.herokuapp.com/vehicles/]
# 5   [https://ghibliapi.herokuapp.com/vehicles/]
# 6   [https://ghibliapi.herokuapp.com/vehicles/]
# 7   [https://ghibliapi.herokuapp.com/vehicles/]
# 8   [https://ghibliapi.herokuapp.com/vehicles/]
# 9   [https://ghibliapi.herokuapp.com/vehicles/]
# 10  [https://ghibliapi.herokuapp.com/vehicles/]
# 11  [https://ghibliapi.herokuapp.com/vehicles/]
#
#                                                   url
# 0   https://ghibliapi.herokuapp.com/films/d868e6ec...
# 1   https://ghibliapi.herokuapp.com/films/dc2e6bd1...
# 2   https://ghibliapi.herokuapp.com/films/90b72513...
# 3   https://ghibliapi.herokuapp.com/films/cd3d059c...
# 4   https://ghibliapi.herokuapp.com/films/112c1e67...
# 5   https://ghibliapi.herokuapp.com/films/758bf02e...
# 6   https://ghibliapi.herokuapp.com/films/2de9426b...
# 7   https://ghibliapi.herokuapp.com/films/45db04e4...
# 8   https://ghibliapi.herokuapp.com/films/67405111...
# 9   https://ghibliapi.herokuapp.com/films/578ae244...
# 10  https://ghibliapi.herokuapp.com/films/5fdfb320...
# 11  https://ghibliapi.herokuapp.com/films/d868e6ec...

# %% [markdown]
# ## 3. Report

# %%
df["rt_score"] = pd.to_numeric(df["rt_score"], errors="coerce")
avg_rt_score=df[["director","rt_score"]].groupby("director")["rt_score"].mean()

director_counts=df["director"].value_counts()

report=pd.merge(avg_rt_score,director_counts,on="director")
report=report.sort_values(by="rt_score",ascending=False)
report
# Out:
#                       rt_score  count
# director
# Isao Takahata           100.00      1
# Hiromasa Yonebayashi     93.50      2
# Michaël Dudok de Wit     93.00      2
# Hayao Miyazaki           91.25      4
# Hiroyuki Morita          89.00      1
# Gorō Miyazaki            62.00      2
